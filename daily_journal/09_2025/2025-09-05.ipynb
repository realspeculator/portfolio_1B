# %% [markdown]
# #### 2025-09-05

# %% [markdown]
# ##### 7:17 AM
#
# We have the monthly jobs report due in little more than an hour today. The markets are rallying and the QQQ have come up almost 3% since September 2nd low.
#
# My portfolios are flat in the last 3 days. While I have made some money on the a few swing positions, I have given it all up in intra-day trading on ES and NQ futures.
#
# So for the time being I will reduce my size to 100 lot on ES and 50 on NQ until I start getting back in the rhythm of this market.
#
# Today also seems to be a good day to review all the individual stock trades done so far in the last 30 or so days.

# %% [markdown]
# Lets review the biggest losers first.

# %% [markdown]
# ##### COIN
#
# COIN	COINBASE GLOBAL INC A	+20,000	341.79	310.85	$81,000.00	($618,800.00)	-9.05%	$6,217,000.00
#
# On this trade I'm down 618000. This is in violation of the max

# %% [markdown]
# ![](https://private-user-images.githubusercontent.com/120210274/486088090-ea7a104e-3a85-4342-b57f-be652d2bb232.png?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmF3LmdpdGh1YnVzZXJjb250ZW50LmNvbSIsImtleSI6ImtleTUiLCJleHAiOjE3NTcwNzMxMTUsIm5iZiI6MTc1NzA3MjgxNSwicGF0aCI6Ii8xMjAyMTAyNzQvNDg2MDg4MDkwLWVhN2ExMDRlLTNhODUtNDM0Mi1iNTdmLWJlNjUyZDJiYjIzMi5wbmc_.nSsC_ZIotaNl3bdR7VJN_r6G43mqnIbFr2IlQ9dVNKs)

# %% [markdown]
# Looking at the monthly chart we can see the Coin is trading at the low of August and has rejected the previous months low. August was a well defined profile and we have a good chance of rallying back to the 325 to 335 area. So I have given this stock a bit of room to work it out.

# %% [markdown]
# ![](https://private-user-images.githubusercontent.com/120210274/486091507-d1479a76-68fc-4baa-b07e-cfef45c7bd40.png?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmF3LmdpdGh1YnVzZXJjb250ZW50LmNvbSIsImtleSI6ImtleTUiLCJleHAiOjE3NTcwNzM3OTcsIm5iZiI6MTc1NzA3MzQ5NywicGF0aCI6Ii8xMjAyMTAyNzQvNDg2MDkxNTA3LWQxNDc5YTc2LTY4ZmMtNGJhYS1iMDdlLWNmZWY0NWM3YmQ0MC5wbmc_.CBy1jV3Zim0V7EX4RpT1Qwf5mJmvxXX3ekFGj4h_-H4)

# %% [markdown]
# In hindsight I should have only taken the trade if there was a balance area between the 336 to 346 area (shaded area). The 4Hour cross also did not confirm this move. The gap acted as a strong resistance.

# %% [markdown]
# ##### SMCI

# %% [markdown]
# ![image.png](attachment:96b78fd0-9ea9-4a99-8e07-c96134fc2b78.png)![image.png](attachment:6f446d7a-3433-47b8-989d-f8485339b40f.png)![image.png](attachment:88826ad3-a274-4c45-b277-d1c60bdc1b46.png)
