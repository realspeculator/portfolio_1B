# %% [markdown]
# #### 2025-08-07
#
# ##### 6:43AM
# Yesterday we got our first draw down on the account. The portfoio had made 18bps in the first 3 trading days. But the drawdown took it under water. Our account value also dipped below its starting point. What positions caused the drawdown? The following losses.
#
#
# ##### TMO STOPPED OUT
#
# Loss -280200
#
# ![image.png](attachment:3f09d1cb-921a-476b-a5b9-09351ba188a0.png)
#
# ##### AAPL Squeeze - Position is still open
#
# Loss -571000
#
# ![image.png](attachment:be153075-b96b-4f79-9719-307357e4494a.png)
#
# ##### NQ
#
# Loss more than 500000
#
# ##### BTC
#
# ![image.png](attachment:cf72e6ab-9e82-4eb3-9d33-1ef88b9356ec.png)

# %% [markdown]
# A pattern seems to be emerging from the above trades. My entery has been made nead critical pivot points. At these points stocks have a tendency to revese themselves. I need to keep my stops very tight.

# %% [markdown]
# So our process to rebuild starts again.

# %% [markdown]
# #### 9:53AM
#
# Trades done so far today.
#
#     8/7/25	01:00:00	BAL	--	Cash balance at the start of business day 07.08 CST	--	--	--	17,788,789.29
# 	06:34:34	TRD	5218718783	BOT +150 /BTCQ25:XCME @116635.00	--	-337.50	-29,157,500.00	-11,369,048.21
# 	09:23:43	TRD	5218745396	BOT +100 /BTCQ25:XCME @116875.00	--	-225.00	--	-11,369,273.21
# 	09:31:34	TRD	5218755253	BOT +100,000 AAPL @216.68	--	--	-21,668,000.00	-33,037,273.21
# 	09:48:21	TRD	5218812863	BOT +250,000 GDXJ @72.80	--	--	-18,200,000.00	-51,237,273.21
# 	09:51:26	TRD	5218821769	BOT +250,000 SMCI @48.70	--	--	-12,175,000.00	-63,412,273.21

# %% [markdown]
# I reversed the AAPL position. Bought some GDXJ and SMCI. Another stock I'm watching is CELH. This could be a multi-month swing trade.
