# %% [markdown]
# #### 2025-08-24
#
# Going on a vacation for a week. I will be back trading on September 3rd.

# %% [markdown]
# Account view as of 2025-08-24
#
# ![image.png](attachment:454f5277-f938-4f99-bdea-ccc76eb0f2a5.png)

# %% [markdown]
# No short positions only a handful (~5% of portfolio) of longs. 95% in cash. Biggest risk is in CELH, COIN

# %% [markdown]
# No trading or account statement uploads for the next 8 days.
