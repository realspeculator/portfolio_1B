# %% [markdown]
# ![Screenshot 2025-08-04 at 8.28.38 AM.png](attachment:f3c75169-fd36-484a-bb10-f66d066c6f49.png)
#
# #### 8:29
# ES is gapping higher. The indicated open of is near the high of friday's range.
#
# ![Screenshot 2025-08-04 at 8.30.03 AM.png](attachment:6ff9d228-8d5c-431d-bde3-114bdce1ce71.png)
#
# Overnight inventory is long.
#
# We might face some resistance at 6313 level, which was the high of Friday.
#
# No Economic events to watch for today. Tomorrow we have ISM services number. We also have earnings from palantir after market close.

# %% [markdown]
# ##### 8:58
#
# ![image.png](attachment:71f23498-96ed-4122-9f91-697e461d5616.png)
#
# Last Friday we had 3 positions open. Short positions on Google and Apple. And a long position on Netflix.

# %% [markdown]
# #### GOOGL
#
# ![image.png](attachment:4213be40-6587-4af8-80d4-5afdd1bb03c1.png)
#
# Google's indicated open is around 190.30. We will continue to hold this, and put a STOP LOSS around 192.
#
# #### AAPL
#
# ![image.png](attachment:741e0788-32e5-4c1d-996e-e55506e74cec.png)
#
# Apple's current indicated open is 203.75. We will hold the short.
#
# #### Netflix
#
# ![image.png](attachment:e9fcf80e-45f2-42a6-b73a-59378d45d820.png)
#
# Netflix's open is below the value area. We will look to close this long position.

# %% [markdown]
# #### 9:19
#
# Plan for today
# - Be in no hurry to trade the open.
# - Let the markets balance.
# - Let it test the HOD for Friday
# - See how they react at that level
# - Rejection of this high could potentially be a good short trade (higher Probability)
# - A breakout of this could grind the markets higher (lower Porbability)

# %% [markdown]
# #### 9:42
#
# ![image.png](attachment:d5e12bf1-f87a-4c8b-bb8c-a9cb136ce39e.png)
#
# We have broken through the 6313 level and are probing higher.

# %% [markdown]
# #### 10:06
#
# I took a few intra day trades.

# %% [markdown]
# 	09:36:08	TRD	5216922078	BOT +300 NDX 100 (Weeklys) 4 AUG 25 23040 CALL @55.40	-1.80	-195.00	-1,662,000.00	9,861,844.53
# 	09:40:14	TRD	5216936770	SOLD -300 NDX 100 (Weeklys) 4 AUG 25 23040 CALL @61.80	-1.80	-195.00	1,854,000.00	11,715,647.73
# 	09:43:45	TRD	5216947455	BOT +75 /NQU25:XCME @23193.00	--	-168.75	--	11,715,478.98
# 	09:43:51	TRD	5216947479	BOT +10 /NQU25:XCME @23194.25	--	-22.50	--	11,715,456.48
# 	09:44:05	TRD	5216948744	BOT +5 /NQU25:XCME @23184.75	--	-11.25	--	11,715,445.23
# 	10:03:29	TRD	5217001656	SOLD -90 /NQU25:XCME @23252.00	--	-202.50	106,775.00	11,822,017.73

# %% [markdown]
# I closed them around the turn of the 30min candle. As I have seen in the past this to be a major turning point.

# %% [markdown]
# ![image.png](attachment:7cc470e8-adcb-46ad-aa13-e77ed7b5ac83.png)

# %% [markdown]
# #### 10:46
#
# Short BTC
#
# ![image.png](attachment:ec2d7974-25ff-4bbe-bc4b-8d2c696489e6.png)
#
# #### 10:52
# Closed it and lowered the position to a more manageable size.
#
# Now short 50 Bitcoin

# %% [markdown]
# #### 10:54
#
# ![image.png](attachment:764b7b01-8903-4904-8549-e3c1141899dd.png)
#
# NQ is turning. But the TICs are still above 0 and AD line is 1500+ and VIX is 18.3

# %% [markdown]
# #### 11:10
#
# Also shorted ETH since there is a high correlation between both ETH and BTC.<br>
# Closed the ETH instead of putting a STOP loss.

# %% [markdown]
# #### 12:06
#
# ![image.png](attachment:c86e2c04-452d-4e4c-ab45-dcd2a331cea5.png)
#
# We have retraced 50% of the down move from friday.
