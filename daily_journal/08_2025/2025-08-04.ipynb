# %% [markdown]
# ![Screenshot 2025-08-04 at 8.28.38 AM.png](attachment:f3c75169-fd36-484a-bb10-f66d066c6f49.png)
#
# #### 8:29
# ES is gapping higher. The indicated open of is near the high of friday's range.
#
# ![Screenshot 2025-08-04 at 8.30.03 AM.png](attachment:6ff9d228-8d5c-431d-bde3-114bdce1ce71.png)
#
# Overnight inventory is long.
#
# We might face some resistance at 6313 level, which was the high of Friday.
#
# No Economic events to watch for today. Tomorrow we have ISM services number. We also have earnings from palantir after market close.

# %% [markdown]
# ##### 8:58
#
# ![image.png](attachment:71f23498-96ed-4122-9f91-697e461d5616.png)
#
# Last Friday we had 3 positions open. Short positions on Google and Apple. And a long position on Netflix.

# %% [markdown]
# #### GOOGL
#
# ![image.png](attachment:4213be40-6587-4af8-80d4-5afdd1bb03c1.png)
#
# Google's indicated open is around 190.30. We will continue to hold this, and put a STOP LOSS around 192.
#
# #### AAPL
#
# ![image.png](attachment:741e0788-32e5-4c1d-996e-e55506e74cec.png)
#
# Apple's current indicated open is 203.75. We will hold the short.
#
# #### Netflix
#
# ![image.png](attachment:e9fcf80e-45f2-42a6-b73a-59378d45d820.png)
#
# Netflix's open is below the value area. We will look to close this long position.
