# %% [markdown]
# #### 2025-08-05

# %% [markdown]
# ![image.png](attachment:1599eb2a-8285-48d2-b7b4-2671a9f37992.png)

# %% [markdown]
# ES is opening right around the high of yesterday. NQ is actually gapping higher than yesterdays open.
#
# We see an ovenight balance area getting formed in this 20 point range.
#
# A break above the 6378 could push us back into the 3 day range. NQ is already gapping higher. so the trade for NQ is to go long at the open.

# %% [markdown]
# #### 9:44
#
# ![image.png](attachment:29f9893a-fa1c-46f4-8cab-a88c06463b7b.png)
#
# At the open I went long 400 NQ contract for a notional position of $186mil. While the position went against me the first 5 mins. It has come back and now breaking out. I bought 100 more at the break out. Now I am long 500 NQ avg price 23353

# %%
# Total Notional 

500 * 20 * 23353
# Out:
# 233530000

# %% [markdown]
# ![image.png](attachment:ac317cb4-3e3d-4a04-a4f4-55af60c16b41.png)
#
# Target is 23752 or 400 points higher.
#
# Major caveat is that TICs are not responding as expected. They are stuck at 100+ level
#
# We are still in the overnight balance area and have yet not broken out of it.

# %% [markdown]
# ![image.png](attachment:85ee7943-0bf5-405b-8a7b-44725a8e2797.png)

# %% [markdown]
# #### 10:15
#
# ![image.png](attachment:df4f2439-e282-4117-a4a2-c271bc92b98f.png)
#
# ES has broken out of the balance area and now trending lower. I have an order open to short ES on any bounce upto the balance area low.

# %% [markdown]
# I am also looking to close the NQ long.

# %% [markdown]
# #### 10:21 AM
#
# I closed the NQ long and reversed the position. Now short 500 NQ at 23999.

# %% [markdown]
# Also bought 100 NDX puts
