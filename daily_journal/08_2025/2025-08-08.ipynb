# %% [markdown]
# #### 2025-08-08
#
# 9:20AM
#
# Today the market is opening in the middle of yesterday's range. More interestingly its above the last 3 days (before yesterday). It maybe a chop type session. Let the market settle and give you a direction.
#
# ##### ES
# ![image.png](attachment:1ebbfb6c-a79e-48f1-92c2-6dc1dffc894c.png)

# %% [markdown]
# ##### BTC
#
# Opportunity may come in the Bitcoin market. Its also opening in the middle of yesterday's range, but it may test 116200, which could be a go place to go long.
#
# ![image.png](attachment:b0c5426b-fcd5-471e-b67e-3474fab96902.png)

# %% [markdown]
# ##### Trade ideas
#
# GDDY, LLY maybe setting up for a good short, that can be held as a swing trade.

# %% [markdown]
# ##### 1:13PM
#
# ![image.png](attachment:92c395a5-fe30-4baf-887c-2789a9f156e9.png)

# %% [markdown]
# Went short using NDX put options.

# %% [markdown]
# #### 1:42
#
# Its a choppy session and we might be drifting higher.

# %% [markdown]
# ##### 2:10
#
# As the week has progressed, the markets have recovered but TICKs have not been confirming this.
#
# ![image.png](attachment:7629d043-b3eb-437e-95b7-a1d26426480f.png)
#
# In the past I have seen such rallies fade. Will it do the same this time or do we just continue to be drifting higher.
